# %% [markdown]
# # Agenda

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

events = ['Intro/Slack', 'Virtualenvs', 'Anaconda', 'Remote debugging with PyCharm', 'Environment management with ~PyCharm']
times  = [5, 15, 15, 15, 15]
explode = [0.2, 0, 0, 0, 0]
plt.pie(times, labels=events, explode=explode, counterclock=False, startangle=90, autopct='%1.f%%') 
plt.axis('equal')
plt.show()

# %%
import google_survey
madpy_habits = google_survey.get('madpy-habits-survey.yaml')
madpy_editors = madpy_habits.loc[madpy_habits.question_id == 'q1']
madpy_editors.response.value_counts().plot.bar()

# %% [markdown]
# # Slack!

# %% [markdown]
# - [slack.madpy.com](https://slack.madpy.com) ← sign up here
# - [madpy.slack.com](https://madpy.slack.com) ← log in here

# %% [markdown]
# ## Channels

# %% [markdown]
# - `#general` ← place to go after a meeting
# - `#random`
# - `#calendar`
# - `#forwardfest` ← Tuesday, August 22
